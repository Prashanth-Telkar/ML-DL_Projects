# %% [markdown]
# # Property Price Prediction Case Study
#
# #### Problem Statement:
#
# Consider a real estate company that has a dataset containing the prices of properties in the Delhi region. It wishes to use the data to optimise the sale prices of the properties based on important factors such as area, bedrooms, parking, etc.
#
# Essentially, the company wants —
#
#
# - To identify the variables affecting house prices, e.g. area, number of rooms, bathrooms, etc.
#
# - To create a linear model that quantitatively relates house prices with variables such as number of rooms, area, number of bathrooms, etc.
#
# - To know the accuracy of the model, i.e. how well these variables can predict house prices.
#
# ### Multiple Linear Regression

# %%
# Importing all the required libraries:
import numpy as np, pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import statsmodels.api as sm
from statsmodels.stats.outliers_influence import variance_inflation_factor

import sklearn
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.feature_selection import RFE
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score

import warnings
warnings.filterwarnings('ignore')

# %%
# Reading the Housing data:
df=pd.read_csv('D:\Machine_learning\Housing.csv')
df
# Out:
#         price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0    13300000  7420         4          2        3      yes        no       no
# 1    12250000  8960         4          4        4      yes        no       no
# 2    12250000  9960         3          2        2      yes        no      yes
# 3    12215000  7500         4          2        2      yes        no      yes
# 4    11410000  7420         4          1        2      yes       yes      yes
# ..        ...   ...       ...        ...      ...      ...       ...      ...
# 540   1820000  3000         2          1        1      yes        no      yes
# 541   1767150  2400         3          1        1       no        no       no
# 542   1750000  3620         2          1        1      yes        no       no
# 543   1750000  2910         3          1        1       no        no       no
# 544   1750000  3850         3          1        2      yes        no       no
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 545 entries, 0 to 544
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   price             545 non-null    int64
#  1   area              545 non-null    int64
#  2   bedrooms          545 non-null    int64
#  3   bathrooms         545 non-null    int64
#  4   stories           545 non-null    int64
#  5   mainroad          545 non-null    object
#  6   guestroom         545 non-null    object
#  7   basement          545 non-null    object
#  8   hotwaterheating   545 non-null    object
#  9   airconditioning   545 non-null    object
#  10  parking           545 non-null    int64
#  11  prefarea          545 non-null    object
#  12  furnishingstatus  545 non-null    object
# dtypes: int64(6), object(7)
# memory usage: 55.5+ KB

# %%
# Separating continuous variables:
df_con=df[['price','area']]
df_con
# Out:
#         price  area
# 0    13300000  7420
# 1    12250000  8960
# 2    12250000  9960
# 3    12215000  7500
# 4    11410000  7420
# ..        ...   ...
# 540   1820000  3000
# 541   1767150  2400
# 542   1750000  3620
# 543   1750000  2910
# 544   1750000  3850
#
# [545 rows x 2 columns]

# %%
# Separating categorical variables:
df_cat=df.iloc[:,2:]
df_cat
# Out:
#      bedrooms  bathrooms  stories mainroad guestroom basement hotwaterheating  \
# 0           4          2        3      yes        no       no              no
# 1           4          4        4      yes        no       no              no
# 2           3          2        2      yes        no      yes              no
# 3           4          2        2      yes        no      yes              no
# 4           4          1        2      yes       yes      yes              no
# ..        ...        ...      ...      ...       ...      ...             ...
# 540         2          1        1      yes        no      yes              no
# 541         3          1        1       no        no       no              no
# 542         2          1        1      yes        no       no              no
# 543         3          1        1       no        no       no              no
# 544         3          1        2      yes        no       no              no
#
# ...

# %%
# Plotting scatter plot for continuous variable:
sns.pairplot(df_con,size=3)
plt.show()

# %%
df_cat
# Out:
#      bedrooms  bathrooms  stories mainroad guestroom basement hotwaterheating  \
# 0           4          2        3      yes        no       no              no
# 1           4          4        4      yes        no       no              no
# 2           3          2        2      yes        no      yes              no
# 3           4          2        2      yes        no      yes              no
# 4           4          1        2      yes       yes      yes              no
# ..        ...        ...      ...      ...       ...      ...             ...
# 540         2          1        1      yes        no      yes              no
# 541         3          1        1       no        no       no              no
# 542         2          1        1      yes        no       no              no
# 543         3          1        1       no        no       no              no
# 544         3          1        2      yes        no       no              no
#
# ...

# %%
# Plotting boxplot for categorical variables:
plt.figure(figsize=[20,20])
plt.subplot(4,3,1)
sns.boxplot(data=df,x='bedrooms',y='price')
plt.subplot(4,3,2)
sns.boxplot(data=df,x='bathrooms',y='price')
plt.subplot(4,3,3)
sns.boxplot(data=df,x='stories',y='price')
plt.subplot(4,3,4)
sns.boxplot(data=df,x='mainroad',y='price')
plt.subplot(4,3,5)
sns.boxplot(data=df,x='guestroom',y='price')
plt.subplot(4,3,6)
sns.boxplot(data=df,x='basement',y='price')
plt.subplot(4,3,7)
sns.boxplot(data=df,x='hotwaterheating',y='price')
plt.subplot(4,3,8)
sns.boxplot(data=df,x='airconditioning',y='price')
plt.subplot(4,3,9)
sns.boxplot(data=df,x='parking',y='price')
plt.subplot(4,3,10)
sns.boxplot(data=df,x='prefarea',y='price')
plt.subplot(4,3,11)
sns.boxplot(data=df,x='furnishingstatus',y='price')
plt.show()

# %%
df[df['bathrooms']==4]
# Out:
#       price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 1  12250000  8960         4          4        4      yes        no       no
#
#   hotwaterheating airconditioning  parking prefarea furnishingstatus
# 1              no             yes        3       no        furnished

# %%
# Since there is only one record with 4 bathrooms, it is dropped.
df=df[df['bathrooms']!=4]
df
# Out:
#         price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0    13300000  7420         4          2        3      yes        no       no
# 2    12250000  9960         3          2        2      yes        no      yes
# 3    12215000  7500         4          2        2      yes        no      yes
# 4    11410000  7420         4          1        2      yes       yes      yes
# 5    10850000  7500         3          3        1      yes        no      yes
# ..        ...   ...       ...        ...      ...      ...       ...      ...
# 540   1820000  3000         2          1        1      yes        no      yes
# 541   1767150  2400         3          1        1       no        no       no
# 542   1750000  3620         2          1        1      yes        no       no
# 543   1750000  2910         3          1        1       no        no       no
# 544   1750000  3850         3          1        2      yes        no       no
#
# ...

# %%
df_cat
# Out:
#      bedrooms  bathrooms  stories mainroad guestroom basement hotwaterheating  \
# 0           4          2        3      yes        no       no              no
# 1           4          4        4      yes        no       no              no
# 2           3          2        2      yes        no      yes              no
# 3           4          2        2      yes        no      yes              no
# 4           4          1        2      yes       yes      yes              no
# ..        ...        ...      ...      ...       ...      ...             ...
# 540         2          1        1      yes        no      yes              no
# 541         3          1        1       no        no       no              no
# 542         2          1        1      yes        no       no              no
# 543         3          1        1       no        no       no              no
# 544         3          1        2      yes        no       no              no
#
# ...

# %%
# Replaceing yes,no with 0 and 1 respectively:
yes_no_col=['mainroad','guestroom','basement','hotwaterheating','airconditioning','prefarea']
df[yes_no_col]=df[yes_no_col].replace({'yes':1,'no':0})
df
# Out:
#         price  area  bedrooms  bathrooms  stories  mainroad  guestroom  \
# 0    13300000  7420         4          2        3         1          0
# 2    12250000  9960         3          2        2         1          0
# 3    12215000  7500         4          2        2         1          0
# 4    11410000  7420         4          1        2         1          1
# 5    10850000  7500         3          3        1         1          0
# ..        ...   ...       ...        ...      ...       ...        ...
# 540   1820000  3000         2          1        1         1          0
# 541   1767150  2400         3          1        1         0          0
# 542   1750000  3620         2          1        1         1          0
# 543   1750000  2910         3          1        1         0          0
# 544   1750000  3850         3          1        2         1          0
#
#      basement  hotwaterheating  airconditioning  parking  prefarea  \
# ...

# %%
# Creating dummy variables for columns with more than two levels:
df=pd.get_dummies(data=df,columns=['bedrooms','bathrooms','stories','parking','furnishingstatus'],drop_first=True)
df
# Out:
#         price  area  mainroad  guestroom  basement  hotwaterheating  \
# 0    13300000  7420         1          0         0                0
# 2    12250000  9960         1          0         1                0
# 3    12215000  7500         1          0         1                0
# 4    11410000  7420         1          1         1                0
# 5    10850000  7500         1          0         1                0
# ..        ...   ...       ...        ...       ...              ...
# 540   1820000  3000         1          0         1                0
# 541   1767150  2400         0          0         0                0
# 542   1750000  3620         1          0         0                0
# 543   1750000  2910         0          0         0                0
# 544   1750000  3850         1          0         0                0
#
#      airconditioning  prefarea  bedrooms_2  bedrooms_3  ...  bathrooms_2  \
# 0                  1         1           0           0  ...            1
# ...

# %%
# Plotting correlation plot using heatmap:
plt.figure(figsize=[25,18])
sns.heatmap(df.corr(),annot=True,cmap='YlGnBu')
plt.show()

# %%
# Splitting df into train and test set:
df_train,df_test=train_test_split(df,train_size=0.7,random_state=100)
df_train
# Out:
#        price  area  mainroad  guestroom  basement  hotwaterheating  \
# 36   8043000  7482         1          0         0                1
# 29   8400000  5500         1          0         1                0
# 484  2870000  3040         0          0         0                0
# 498  2660000  2000         1          0         0                0
# 172  5250000  8400         1          1         1                0
# ..       ...   ...       ...        ...       ...              ...
# 527  2275000  1836         0          0         1                0
# 54   7350000  6000         1          1         0                0
# 351  3780000  3600         1          0         0                0
# 80   6629000  6000         1          0         0                1
# 521  2408000  3635         0          0         0                0
#
#      airconditioning  prefarea  bedrooms_2  bedrooms_3  ...  bathrooms_2  \
# 36                 0         1           0           1  ...            1
# ...

# %%
df_test.shape
# Out:
# (164, 23)

# %%
# Initialising MinMaxScaler:
scaler=MinMaxScaler()

# %%
# Fitting the scaler to train set:
var=['price','area']
df_train[var]=scaler.fit_transform(df_train[var])
df_train
# Out:
#         price      area  mainroad  guestroom  basement  hotwaterheating  \
# 36   0.544848  0.418065         1          0         0                1
# 29   0.575758  0.275986         1          0         1                0
# 484  0.096970  0.099642         0          0         0                0
# 498  0.078788  0.025090         1          0         0                0
# 172  0.303030  0.483871         1          1         1                0
# ..        ...       ...       ...        ...       ...              ...
# 527  0.045455  0.013333         0          0         1                0
# 54   0.484848  0.311828         1          1         0                0
# 351  0.175758  0.139785         1          0         0                0
# 80   0.422424  0.311828         1          0         0                1
# 521  0.056970  0.142294         0          0         0                0
#
#      airconditioning  prefarea  bedrooms_2  bedrooms_3  ...  bathrooms_2  \
# ...

# %%
df_train.describe()
# Out:
#             price        area    mainroad   guestroom    basement  \
# count  380.000000  380.000000  380.000000  380.000000  380.000000
# mean     0.258700    0.253962    0.860526    0.171053    0.347368
# std      0.156658    0.155842    0.346897    0.377051    0.476762
# min      0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.151515    0.139785    1.000000    0.000000    0.000000
# 50%      0.221818    0.212616    1.000000    0.000000    0.000000
# 75%      0.346212    0.341935    1.000000    0.000000    1.000000
# max      1.000000    1.000000    1.000000    1.000000    1.000000
#
#        hotwaterheating  airconditioning    prefarea  bedrooms_2  bedrooms_3  \
# count       380.000000       380.000000  380.000000  380.000000  380.000000
# mean          0.047368         0.313158    0.226316    0.255263    0.531579
# std           0.212706         0.464389    0.418998    0.436584    0.499660
# ...

# %%
# Separating target variable and predictor variables:
y_train=df_train.pop('price')
X_train=df_train
X_train
# Out:
#          area  mainroad  guestroom  basement  hotwaterheating  \
# 36   0.418065         1          0         0                1
# 29   0.275986         1          0         1                0
# 484  0.099642         0          0         0                0
# 498  0.025090         1          0         0                0
# 172  0.483871         1          1         1                0
# ..        ...       ...        ...       ...              ...
# 527  0.013333         0          0         1                0
# 54   0.311828         1          1         0                0
# 351  0.139785         1          0         0                0
# 80   0.311828         1          0         0                1
# 521  0.142294         0          0         0                0
#
#      airconditioning  prefarea  bedrooms_2  bedrooms_3  bedrooms_4  ...  \
# 36                 0         1           0           1           0  ...
# 29                 1         1           0           0           1  ...
# ...

# %%
# Initialising LR model using sklearn
lr=LinearRegression()

# %%
# Fitting LR model using sklearn
lr=lr.fit(X_train,y_train)

# %%
# Reducing the columns to 12 using Recursive Feature Elimination:
rfe=RFE(lr,15)
rfe=rfe.fit(X_train,y_train)

# %%
list(zip(X_train.columns,rfe.support_,rfe.ranking_))
# Out:
# [('area', True, 1),
#  ('mainroad', True, 1),
#  ('guestroom', False, 4),
#  ('basement', True, 1),
#  ('hotwaterheating', True, 1),
#  ('airconditioning', True, 1),
#  ('prefarea', True, 1),
#  ('bedrooms_2', False, 7),
#  ('bedrooms_3', False, 3),
#  ('bedrooms_4', True, 1),
#  ('bedrooms_5', False, 2),
#  ('bedrooms_6', True, 1),
#  ('bathrooms_2', True, 1),
#  ('bathrooms_3', True, 1),
#  ('stories_2', False, 6),
#  ('stories_3', True, 1),
#  ('stories_4', True, 1),
#  ('parking_1', True, 1),
#  ('parking_2', True, 1),
#  ('parking_3', False, 5),
#  ('furnishingstatus_semi-furnished', False, 8),
#  ('furnishingstatus_unfurnished', True, 1)]

# %%
# Creating reduced set of predictor variables:
X_train_rfe=X_train[X_train.columns[rfe.support_]]
X_train_rfe
# Out:
#          area  mainroad  basement  hotwaterheating  airconditioning  prefarea  \
# 36   0.418065         1         0                1                0         1
# 29   0.275986         1         1                0                1         1
# 484  0.099642         0         0                0                0         0
# 498  0.025090         1         0                0                0         0
# 172  0.483871         1         1                0                1         1
# ..        ...       ...       ...              ...              ...       ...
# 527  0.013333         0         1                0                0         0
# 54   0.311828         1         0                0                1         0
# 351  0.139785         1         0                0                0         0
# 80   0.311828         1         0                1                0         1
# 521  0.142294         0         0                0                0         0
#
# ...

# %%
X_train_rfe_sm=sm.add_constant(X_train_rfe)
X_train_rfe_sm
# Out:
#      const      area  mainroad  basement  hotwaterheating  airconditioning  \
# 36     1.0  0.418065         1         0                1                0
# 29     1.0  0.275986         1         1                0                1
# 484    1.0  0.099642         0         0                0                0
# 498    1.0  0.025090         1         0                0                0
# 172    1.0  0.483871         1         1                0                1
# ..     ...       ...       ...       ...              ...              ...
# 527    1.0  0.013333         0         1                0                0
# 54     1.0  0.311828         1         0                0                1
# 351    1.0  0.139785         1         0                0                0
# 80     1.0  0.311828         1         0                1                0
# 521    1.0  0.142294         0         0                0                0
#
# ...

# %%
lr=sm.OLS(y_train,X_train_rfe_sm).fit()

# %%
lr.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.662
# Model:                            OLS   Adj. R-squared:                  0.648
# Method:                 Least Squares   F-statistic:                     47.54
# Date:                Sat, 05 Jun 2021   Prob (F-statistic):           3.69e-76
# Time:                        01:01:13   Log-Likelihood:                 371.84
# No. Observations:                 380   AIC:                            -711.7
# Df Residuals:                     364   BIC:                            -648.6
# Df Model:                          15
# Covariance Type:            nonrobust
# ...
#                                    coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------
# ...

# %%
# Checking the Variance Inflation Factor:
vif=pd.DataFrame()
vif['Columns']=X_train_rfe.columns
vif['VIF']=[variance_inflation_factor(X_train_rfe.values,i) for i in range(X_train_rfe.shape[1])]
vif=vif.sort_values(by='VIF',ascending=False)
vif=vif.round(2)
vif
# Out:
#                          Columns   VIF
# 1                       mainroad  4.63
# 0                           area  4.41
# 2                       basement  1.84
# 8                    bathrooms_2  1.76
# 4                airconditioning  1.69
# 13                     parking_2  1.59
# 12                     parking_1  1.57
# 5                       prefarea  1.54
# 6                     bedrooms_4  1.38
# 11                     stories_4  1.33
# 14  furnishingstatus_unfurnished  1.32
# 10                     stories_3  1.22
# 3                hotwaterheating  1.14
# 9                    bathrooms_3  1.10
# 7                     bedrooms_6  1.03

# %%
# Dropping 'bedrooms_6' and Rebuilding the LR model:
X_train_rfe=X_train_rfe.drop('bedrooms_6',axis=1)
X_train_rfe_sm=sm.add_constant(X_train_rfe)
lr=sm.OLS(y_train,X_train_rfe_sm).fit()
lr.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.662
# Model:                            OLS   Adj. R-squared:                  0.649
# Method:                 Least Squares   F-statistic:                     51.06
# Date:                Sat, 05 Jun 2021   Prob (F-statistic):           5.23e-77
# Time:                        01:01:13   Log-Likelihood:                 371.80
# No. Observations:                 380   AIC:                            -713.6
# Df Residuals:                     365   BIC:                            -654.5
# Df Model:                          14
# Covariance Type:            nonrobust
# ...
#                                    coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------
# ...

# %%
# Checking the Variance Inflation Factor:
vif=pd.DataFrame()
vif['Columns']=X_train_rfe.columns
vif['VIF']=[variance_inflation_factor(X_train_rfe.values,i) for i in range(X_train_rfe.shape[1])]
vif=vif.sort_values(by='VIF',ascending=False)
vif=vif.round(2)
vif
# Out:
#                          Columns   VIF
# 1                       mainroad  4.63
# 0                           area  4.40
# 2                       basement  1.84
# 7                    bathrooms_2  1.76
# 4                airconditioning  1.69
# 12                     parking_2  1.59
# 11                     parking_1  1.55
# 5                       prefarea  1.54
# 6                     bedrooms_4  1.38
# 10                     stories_4  1.33
# 13  furnishingstatus_unfurnished  1.31
# 9                      stories_3  1.22
# 3                hotwaterheating  1.14
# 8                    bathrooms_3  1.10

# %% [markdown]
# **Now since the p_value for all the variables are significant and VIF for all the variables is < 5, the Linear Regression Model is finalised.**

# %% [markdown]
# ## **Residual Analysis**

# %%
# Getting predicted values for train data set:
y_train_pred=lr.predict(X_train_rfe_sm)
y_train_pred
# Out:
# 36     0.533206
# 29     0.485432
# 484    0.043366
# 498    0.101230
# 172    0.402975
#          ...
# 527    0.096222
# 54     0.369953
# 351    0.131586
# 80     0.354927
# 521    0.054655
# Length: 380, dtype: float64

# %%
# Residual:
res=y_train-y_train_pred

# %%
# Plotting distribution plot for residual:
plt.figure(figsize=[7,5])
sns.distplot(res)
plt.show()

# %% [markdown]
# **As we can see the curve looks like Normal distribution with mean 0. Hence our model is inline with the assumption that the error is normally distributed with zero mean.**

# %%
# Checking for patterns in residual:
plt.figure(figsize=[7,5])
sns.regplot(y_train_pred,res)
plt.show()

# %% [markdown]
# **Since we cannot see any patterns in error, our LR model is in line with the assumption that errors are independent of each other.**

# %% [markdown]
# Hence our model holds good for the following assumptions of simple linear regression:
#
# 1. Linear relationship between X and Y
# 2. Error terms are normally distributed
# 3. Error terms are independent of each other
# 4. Error terms have constant variance (homoscedasticity)

# %% [markdown]
# ## Model Evaluation

# %% [markdown]
# **Now we validate our model using test df**

# %%
df_test[var]
# Out:
#        price  area
# 26   8463000  6000
# 55   7350000  6000
# 242  4550000  3640
# 492  2800000  2650
# 245  4550000  5360
# ..       ...   ...
# 47   7490000  6600
# 51   7420000  6325
# 357  3773000  6930
# 20   8750000  4320
# 160  5460000  6210
#
# [164 rows x 2 columns]

# %%
true_cnt_test=df_test['price']

# %%
# Transforming the test data:
df_test[var]=scaler.transform(df_test[var])
df_test
# Out:
#         price      area  mainroad  guestroom  basement  hotwaterheating  \
# 26   0.581212  0.311828         1          1         1                0
# 55   0.484848  0.311828         1          0         0                0
# 242  0.242424  0.142652         1          0         0                0
# 492  0.090909  0.071685         1          0         1                0
# 245  0.242424  0.265950         1          0         0                0
# ..        ...       ...       ...        ...       ...              ...
# 47   0.496970  0.354839         1          0         0                0
# 51   0.490909  0.335125         1          0         0                0
# 357  0.175152  0.378495         0          0         0                0
# 20   0.606061  0.191398         1          0         1                1
# 160  0.321212  0.326882         1          1         0                0
#
#      airconditioning  prefarea  bedrooms_2  bedrooms_3  ...  bathrooms_2  \
# ...

# %%
df_test[var].describe()
# Out:
#             price        area
# count  164.000000  164.000000
# mean     0.263004    0.242255
# std      0.166940    0.154087
# min      0.006061    0.018280
# 25%      0.139394    0.137097
# 50%      0.233030    0.204301
# 75%      0.339773    0.320968
# max      0.909091    1.043011

# %%
y_test=df_test.pop('price')
X_test=df_test

# %%
# Filtering the columns required for the model input:
X_test=df_test[X_train_rfe.columns]
X_test
# Out:
#          area  mainroad  basement  hotwaterheating  airconditioning  prefarea  \
# 26   0.311828         1         1                0                1         1
# 55   0.311828         1         0                0                1         0
# 242  0.142652         1         0                0                1         0
# 492  0.071685         1         1                0                0         0
# 245  0.265950         1         0                0                0         1
# ..        ...       ...       ...              ...              ...       ...
# 47   0.354839         1         0                0                1         1
# 51   0.335125         1         0                0                1         0
# 357  0.378495         0         0                0                0         0
# 20   0.191398         1         1                1                0         0
# 160  0.326882         1         0                0                1         0
#
# ...

# %%
# Adding constant:
X_test_sm=sm.add_constant(X_test)
X_test_sm
# Out:
#      const      area  mainroad  basement  hotwaterheating  airconditioning  \
# 26     1.0  0.311828         1         1                0                1
# 55     1.0  0.311828         1         0                0                1
# 242    1.0  0.142652         1         0                0                1
# 492    1.0  0.071685         1         1                0                0
# 245    1.0  0.265950         1         0                0                0
# ..     ...       ...       ...       ...              ...              ...
# 47     1.0  0.354839         1         0                0                1
# 51     1.0  0.335125         1         0                0                1
# 357    1.0  0.378495         0         0                0                0
# 20     1.0  0.191398         1         1                1                0
# 160    1.0  0.326882         1         0                0                1
#
# ...

# %%
# Predicting the results for test set:
y_test_pred=lr.predict(X_test_sm)
y_test_pred
# Out:
# 26     0.555431
# 55     0.250630
# 242    0.209012
# 492    0.148131
# 245    0.230905
#          ...
# 47     0.447737
# 51     0.378359
# 357    0.216193
# 20     0.307857
# 160    0.405569
# Length: 164, dtype: float64

# %% [markdown]
# ## Results and Conclusion

# %%
# Plotting regression plot for train and test set:
plt.figure(figsize=[15,5])
plt.subplot(1,2,1)
sns.regplot(y_train,y_train_pred)
plt.xlabel('y_train')
plt.ylabel('y_train_pred')
plt.title('Training Set')
plt.subplot(1,2,2)
sns.regplot(y_test,y_test_pred)
plt.title('Test Set')
plt.xlabel('y_test')
plt.ylabel('y_test_pred')
plt.show()

# %%
# Comparing the Rsquare:
print(r2_score(y_train,y_train_pred))
print(r2_score(y_test,y_test_pred))
# Out:
# 0.6620050924320675
# 0.6628062969940967

# %% [markdown]
# **Thus, for the model with 14 variables, the r-squared on training and test data is about 66.2% and 66.28% respectively.**
#
# **The adjusted r-squared on the train set is about is about 64.9%.**

# %%
# Plotting correlation using heatmap:
plt.figure(figsize=[15,10])
sns.heatmap(X_train_rfe.corr(),annot=True,cmap='YlGnBu')
plt.show()

# %% [markdown]
# **This is the simplest model that we could build. The final predictors seem to have fairly low correlations.**
#
# **Thus, the final model consists of the 14 variables mentioned above. One can go ahead with this model and use it for predicting the prices of properties in Delhi.**
